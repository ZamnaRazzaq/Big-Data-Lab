# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# TASK 1

# %%
df=pd.read_csv('na-nov2021-agriculture-csv.csv')
print(df)
y=df.iloc[:,2]      #data values
x=df.iloc[:,9]      #series title
x=x.fillna(x.mode())   # fill with mode
y=y.fillna(y.mean())   # fill with mean
df.head()

fig = plt.figure(figsize =(50,7))  # BAR GRAPH
plt.bar(x,y)
plt.xlabel("Series Title")
plt.ylabel("Data Value")


fig = plt.figure(figsize =(50,7))   # SCATTER GRAPH
plt.scatter(x,y)
plt.xlabel("Series Title")
plt.ylabel("Data Value")


fig = plt.figure(figsize =(50,7))  # LINE GRAPH
plt.plot(x,y)
plt.xlabel("Series Title")
plt.ylabel("Data Value")
plt.show()


fig = plt.figure(figsize =(10, 30))  #PIE CHART
plt.pie(y,labels=y)
plt.show()
# Out:
#          Series_reference   Period  Data_value   STATUS   UNITS  MAGNTUDE  \
# 0    SNEA.SG01NAC16P10A11  2007.03         526    FINAL  Dollar         6
# 1    SNEA.SG01NAC16P10A11  2008.03         482    FINAL  Dollar         6
# 2    SNEA.SG01NAC16P10A11  2009.03         404    FINAL  Dollar         6
# 3    SNEA.SG01NAC16P10A11  2010.03         450    FINAL  Dollar         6
# 4    SNEA.SG01NAC16P10A11  2011.03         563    FINAL  Dollar         6
# ..                    ...      ...         ...      ...     ...       ...
# 415  SNEA.SG01NAC16P20A99  2016.03       13549    FINAL  Dollar         6
# 416  SNEA.SG01NAC16P20A99  2017.03       13881    FINAL  Dollar         6
# 417  SNEA.SG01NAC16P20A99  2018.03       14788    FINAL  Dollar         6
# 418  SNEA.SG01NAC16P20A99  2019.03       15773  REVISED  Dollar         6
# 419  SNEA.SG01NAC16P20A99  2020.03       16564    FINAL  Dollar         6
#
#                                 Subject  \
# ...

# %% [markdown]
# TASK 2

# %%
import csv
import random
with open('University.csv', 'w', newline='') as file:                     #CSV FILE
  writer = csv.writer(file)
  names=['Ali', 'Amna', 'Hira', 'Asim', 'Asma', 'Dania']
  writer.writerow(["Name", "Age", "Height","CGPA"])
  for i in range(0,1000):
     writer.writerow(([
    (random.choice(names)),(int(random.randint(18,24))),
    (int(random.randint(65,75))),
    (round((random.uniform(2.5,4.0)),2))]))

# %%
df=pd.read_csv('University.csv')
df['Age'].value_counts().plot(kind='bar')
plt.title('Age')
# Out:
# Text(0.5, 1.0, 'Age')

# %%
df['Age'].value_counts().plot(kind='line')
plt.title('Line graph')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %%
df['Height'].value_counts().plot(kind='bar')
plt.title('Height')
# Out:
# Text(0.5, 1.0, 'Height')

# %%
df['Height'].value_counts().plot(kind='line')
plt.title('Line graph')
plt.xlabel('Height')
# Out:
# Text(0.5, 0, 'Height')

# %%
df['CGPA'].value_counts().plot(kind='bar')
plt.title('CGPA')
# Out:
# Text(0.5, 1.0, 'CGPA')

# %%
df['CGPA'].value_counts().plot(kind='line')
plt.title('Line graph')
plt.xlabel('CGPA')
# Out:
# Text(0.5, 0, 'CGPA')

# %% [markdown]
# TASK 3

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn import utils
from sklearn import metrics
from sklearn.metrics import accuracy_score
import joblib
data = pd.read_csv('University.csv')
x = data['Age'].values
y = data['CGPA'].values
y=y.astype(str)
x = x.reshape(-1,1)
y = y.reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(x, y,test_size=0.4, random_state=1)
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.005
# /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
y_pred.reshape(-1,1)
# Out:
# array([['2.62'],
#        ['3.47'],
#        ['2.64'],
#        ['2.64'],
#        ['2.78'],
#        ['2.55'],
#        ['2.64'],
#        ['2.64'],
#        ['3.47'],
#        ['2.55'],
#        ['2.52'],
#        ['2.64'],
#        ['3.47'],
#        ['3.1'],
#        ['2.62'],
#        ['2.62'],
#        ['3.47'],
#        ['2.62'],
#        ['2.52'],
#        ['2.52'],
#        ['2.64'],
#        ['2.55'],
#        ['2.62'],
#        ['2.62'],
#        ['3.47'],
#        ['2.78'],
#        ['2.64'],
#        ['2.62'],
#        ['2.64'],
#        ['2.78'],
#        ['3.47'],
#        ['2.52'],
#        ['2.64'],
#        ['2.55'],
#        ['2.55'],
#        ['3.47'],
#        ['2.64'],
#        ['2.62'],
#        ['2.52'],
#        ['3.47'],
#        ['2.55'],
#        ['2.78'],
#        ['3.1'],
#        ['2.62'],
#        ['2.64'],
#        ['3.47'],
#        ['2.55'],
#        ['2.64'],
#        ['3.1'],
#        ['2.52'],
#        ['3.47'],
#        ['2.78'],
# ...

# %%
joblib.dump(knn, "knn_model.pkl")
# Load the saved model
loaded_model = joblib.load("knn_model.pkl")
# Evaluate the model on the test data
score = loaded_model.score(X_test, y_test)
print("Model Score:", score)
# Out:
# Model Score: 0.005
